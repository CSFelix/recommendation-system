# %% [markdown]
# <center>
#     <h1 id='hypothesis-testing' style='color:#7159c1'>🧪 Hypothesis Testing 🧪</h1>
#     <i>Testing hypothesis on animes average scores</i>
# </center>
#
# > **Topics**
#
# ```
# - 🔑 Key Concepts
# - 🔬 Testing on Anime Datasets
# ```

# %% [markdown]
# <h1 id='0-key-concepts' style='color:#7159c1; border-bottom:3px solid #7159c1; letter-spacing:2px; font-family:JetBrains Mono; font-weight: bold; text-align:left; font-size:240%;padding:0'>🔑 | Key Concepts</h1>
#
# I will make the key concepts explanations as clearer as possible, so let's create a plot here: "Assume we are working for MyAnimeList Analytics Sector as Data Scientists and the owner wants to know if the average score of the shounen animes is the same of the seinen animes.". You may be wondering: *"It is simple, we have just to see the average scores of all shounen and seinen animes and compare them!"*. I am afraid to say but you are wrong 😥
#
# When dealing with problems similar to this one, a number is not a number, but yes, a number is a range of values in Statistics. *"Oh Felix, so you are saying that an average score of 8.0 for shounen animes does not mean 8.0, but a range that goes from 7.0 to 9.0, for instance?"*. Yes, you are totally right!! There is only one thing to highlight here: the boundaries!!
#
# The boundaries limit is determined accordingly to the type of Hypothesis Testing we are applying and to the Confidence Level. Do not worry, soon you will know what Confidence Level and other key parameters are, so let's keep going on our plot.

# %% [markdown]
# <p style='color:#7159c1; letter-spacing:2px; font-family:JetBrains Mono; font-size:150%'>0.0 | Hypothesis</p>
#
# So, our goal in this problem is to determine if the shounen animes average score and the seinen animes average score are equal. For this, we have two conclusions: the averages are equal and the averages are not equal. These two possible conclusions are called **Hypothesis**.
#
# The first Hypothesis is called **Null Hypothesis** that always tell that nothing uncommon is happening, that is, it tells that the averages are equal and both data from shounen and seinen animes came from the same population.
#
# In the other hand, we have the **Alternative Hypothesis** that always tell that something uncommon is happening, that is, it tells that the averages are not equal and both data from shounen and seinen animes came from different populations.
#
# Statistically speaking, we have:
#
# > **Null Hypothesis (H0)** - `anything uncommon is happening because the datas are from the same population`
#
# $$
# \text{H0}: \overline X(shounen) = \overline X(seinen)
# $$
#
# > **Alternative Hypothesis (H1)** - `something uncommon is happening because the datas are from different populations`
#
# $$
# \text{H1}: \overline X(shounen) < \overline X(seinen) \\
# \lor \\
# \text{H1}: \overline X(shounen) \neq \overline X(seinen) \\
# \lor \\
# \text{H1}: \overline X(shounen) > \overline X(seinen)
# $$
#
# <br />
#
# Having this in mind, the possible outcomes we can achieve after applying the testings are:
#
# > **Fail to Reject the Null Hypothesis (H0)** - `shounen and seinen animes have the same average score and are from the same population`;
#
# > **Reject the Null Hypothesis** - `shounen and seinen animes have different average scores and are from different populations`.
#
# <br />
#
# Now, we are heading to where the Hypothesis Testing becomes interesting and I am going to blow up your mind. Even though we can fail to reject or reject the Null Hypothesis, there is the possibility that our result is wrong, right? For example, when we do a Math exam on school, even though we get a result in our calculations, there is the possibility that the result is wrong and we miss the question; the same thing can happen in Hypothesis Testing. We call them **Errors** and they are bummers 😥
#
# There are two types of Errors and we will learn key concepts and techniques to decrease the possibility of making them. For now, let's see what their types are:
#
# > **Error Type 1 - False Positive** - `the Null Hypothesis is rejected when it should be failed to be rejected. For instance, we concluded that the average score of shounen animes is different from the average score of seinen animes when they are actually equals`;
#
# > **Error Type 2 - False Negative** - `the Null Hypothesis failed to be rejected when it should be rejected. For instance, we concluded that the average score of shounen animes and the average score of seinen animes are equal when they are actually differents`.
#
# <br />
#
# It is kind of confusing, isn't it? Even I took some time to fully understand when typing it. A tiny hint for you: read it carefully and without hurry until it makes sense, because everything we are going to cover next depends on these concepts!!

# %% [markdown]
# <p style='color:#7159c1; letter-spacing:2px; font-family:JetBrains Mono; font-size:150%'>0.1 | Level Regions</p>
#
# Assume that we are talking to the MyAnimeList's owner and he asks us: *"So is the average score of shounen animes equal or different of the average score of seinen animes?"*, and we answer: *"With 100% of certainty and considering that the range of the average scores goes from 0 to 10, the averages are equals!"*. The owner will probably be pissed off on us. Why? Hehe...
#
# Since the scores goes from 0 to 10, when we consider that the average range also goes from 0 to 10, all averages are equal, because their range will always be between 0 and 10, got you?
#
# So, with a 100% of certainty, we can assume that the averages are the same, but since we are taking the minimum and the maximum possible values as the range boundaries, our conclusion is poor and contains no valuable insight. So, instead of having 100% of certainty and making a poor conclusion, what about we allow us to have some uncertainty about the result but make a richer conclusion? Are you going to take the risk? Yes? So do I!!
#
# Normally, **95% (0.95)** is a common acceptable certainty whereas **5% (0.05)** is a common acceptable uncertainty. However, these percentages changes accordingly to the problem and to the risk the client and the Data Scientist decide to handle. For our plot, these percentages are fine!! So, now we are going to give a conclusion that has a chance of 95% (0.95) to be correct and 5% (0.05) to be wrong.
#
# For our conclusion, we have to use the data to calculate the probability of getting a wrong conclusion if we choose to reject the Null Hypothesis when it should be failed to be rejected, that is, the probability of making a **Type 1 Error**. This probability is called **p-value**, goes from 0 to 1 and if it is smaller than the Significance Level, we reject the Null Hypothesis; otherwise, we fail to reject the Null Hypothesis.
#
# In Statistics we call the acceptable certainty as **Confidence Level**, and the acceptable uncertainty as **Significance Level**, being:
#
# > **Confidence Level** - `region/area on a Normal Distribution that shows the probability to the Null Hypothesis be failed to be rejected`;
#
# > **Significance Level** - `region/area on a Normal Distribution that shows the probability to the Null Hypothesis be rejected`;
#
# > **P-Value** - `probability of getting a wrong conclusion if we choose to reject the Null Hypothesis when it should be failed to be rejected. Statistically speaking, it is the probability of making a Type 1 Error`.
#
# `When it is smaller than the Significance Level, it means that the probability of making a Type 1 Error is tiny and we can reject the Null Hypothesis. When it is equal or greater than the Significance Level, it means that the probability of making a Type 1 Error is large and we can fail to reject the Null Hypothesis.`
#
# <br />
#
# To a better understanding, let's use a Normal Distribution Histogram and Brazilian women heights - my bad, but StatQuest did not use animes genres in its videos, hope that it is not twisted to follow up 😥
#
# <figure style='text-align:center'>
#     <img style='border-radius:20px' src='./assets/11.0-normal-distribution-height.png' alt='A Normal Distribution of Brazilian women heights in 1996' />
#     <figcaption style='text-align: center'>Figure 1 - A Normal Distribution of Brazilian women heights in 1996. By <a href='https://www.youtube.com/watch?v=JQc3yx0-Q9E'>StatQuest with Josh Starmer - How to calculate p-values©</a>, at 12:48 minutes.</figcaption>
# </figure>
#
# <br />
# <br />
#
# Considering a Confidence Level of 95%, we have the red region representing the area where the Null Hypothesis fails to be rejected.
#
# <figure style='text-align:center'>
#     <img style='border-radius:20px' src='./assets/11.1-normal-distribution-confidence-level.png' alt='Confidence Level in the Normal Distribution of Brazilian women heights' />
#     <figcaption style='text-align: center'>Figure 2 - Confidence Level in the Normal Distribution of Brazilian women heights. By <a href='https://www.youtube.com/watch?v=JQc3yx0-Q9E'>StatQuest with Josh Starmer - How to calculate p-values©</a>, at 13:38 minutes.</figcaption>
# </figure>
#
# <br />
# <br />
#
# And 5% for Significance Level, we have 2.5% in the right side and 2.5% in the left side of the Distribution. Yes, accordingly to the Hypothesis, the Significance Level can be divided into two regions or not. Since this example we are checking if the means are different or not, regardless if the difference tells that one mean is greater than or smaller than the another one, the uncertainty probability is divided into two parts, one to the right side and another one to the left side of the distribution.
#
# <figure style='text-align:center'>
#     <img style='border-radius:20px' src='./assets/11.2-normal-distribution-significance-level.png' alt='Significance Level on the right side of the Normal Distribution of Brazilian women heights' />
#     <figcaption style='text-align: center'>Figure 3 - Significance Level on the right side of the Normal Distribution of Brazilian women heights. By <a href='https://www.youtube.com/watch?v=JQc3yx0-Q9E'>StatQuest with Josh Starmer - How to calculate p-values©</a>, at 14:03 minutes.</figcaption>
# </figure>
#
# <br />
#
# <figure style='text-align:center'>
#     <img style='border-radius:20px' src='./assets/11.3-normal-distribution-significance-level.png' alt='Significance Level on the left side of the Normal Distribution of Brazilian women heights' />
#     <figcaption style='text-align: center'>Figure 4 - Significance Level on the left side of the Normal Distribution of Brazilian women heights. By <a href='https://www.youtube.com/watch?v=JQc3yx0-Q9E'>StatQuest with Josh Starmer - How to calculate p-values©</a>, at 14:08 minutes.</figcaption>
# </figure>
#
# <br />
# <br />
#
# If we measure a bunch of women and get 141 cm as the average height, we can conclude that the mean of our sample is different of the Brazilian women height mean and they are from different populations. The images below ilustrate the step-by-step of this conclusion.
#
# <figure style='text-align:center'>
#     <img style='border-radius:20px' src='./assets/11.4-normal-distribution-p-value.png' alt='P-Value calculation for a women with 141 cm of height' />
#     <figcaption style='text-align: center'>Figure 5 - P-Value calculation for a women with 141 cm of height. By <a href='https://www.youtube.com/watch?v=JQc3yx0-Q9E'>StatQuest with Josh Starmer - How to calculate p-values©</a>, at 17:03 minutes.</figcaption>
# </figure>
#
# <br />
#
# <figure style='text-align:center'>
#     <img style='border-radius:20px' src='./assets/11.5-normal-distribution-p-value.png' alt='P-Value calculation for a women with 141 cm of height in the left side of the Distribution' />
#     <figcaption style='text-align: center'>Figure 6 - P-Value calculation for a women with 141 cm of height in the left side of the Distribution. By <a href='https://www.youtube.com/watch?v=JQc3yx0-Q9E'>StatQuest with Josh Starmer - How to calculate p-values©</a>, at 17:08 minutes.</figcaption>
# </figure>
#
# <br />
#
# <figure style='text-align:center'>
#     <img style='border-radius:20px' src='./assets/11.6-normal-distribution-p-value.png' alt='P-Value calculation for a women with 141 cm of height in the right side of the Distribution' />
#     <figcaption style='text-align: center'>Figure 7 - P-Value calculation for a women with 141 cm of height in the right side of the Distribution. By <a href='https://www.youtube.com/watch?v=JQc3yx0-Q9E'>StatQuest with Josh Starmer - How to calculate p-values©</a>, at 17:08 minutes.</figcaption>
# </figure>
#
# <br />
#
# <figure style='text-align:center'>
#     <img style='border-radius:20px' src='./assets/11.7-normal-distribution-p-value.png' alt='P-Value result for a women with 141 cm of height' />
#     <figcaption style='text-align: center'>Figure 8 - P-Value result for a women with 141 cm of height. By <a href='https://www.youtube.com/watch?v=JQc3yx0-Q9E'>StatQuest with Josh Starmer - How to calculate p-values©</a>, at 17:18 minutes.</figcaption>
# </figure>
#
# <br />
#
# <figure style='text-align:center'>
#     <img style='border-radius:20px' src='./assets/11.8-normal-distribution-p-value.png' alt='P-Value conclusion for a women with 141 cm of height' />
#     <figcaption style='text-align: center'>Figure 9 - P-Value conclusion for a women with 141 cm of height. By <a href='https://www.youtube.com/watch?v=JQc3yx0-Q9E'>StatQuest with Josh Starmer - How to calculate p-values©</a>, at 17:33 minutes.</figcaption>
# </figure>
#
# <br />
#
# <figure style='text-align:center'>
#     <img style='border-radius:20px' src='./assets/11.9-normal-distribution-p-value.png' alt='P-Value conclusion for a women with 141 cm of height' />
#     <figcaption style='text-align: center'>Figure 10 - P-Value conclusion for a women with 141 cm of height. By <a href='https://www.youtube.com/watch?v=JQc3yx0-Q9E'>StatQuest with Josh Starmer - How to calculate p-values©</a>, at 17:33 minutes.</figcaption>
# </figure>
#
# <br />
#
# <figure style='text-align:center'>
#     <img style='border-radius:20px' src='./assets/11.10-normal-distribution-p-value.png' alt='P-Value conclusion for a women with 141 cm of height' />
#     <figcaption style='text-align: center'>Figure 11 - P-Value conclusion for a women with 141 cm of height. By <a href='https://www.youtube.com/watch?v=JQc3yx0-Q9E'>StatQuest with Josh Starmer - How to calculate p-values©</a>, at 17:33 minutes.</figcaption>
# </figure>
#
# <br />
# <br />
#
# Now that we already know what metrics we use to reject or fail to reject H0, let's learn a little more about the p-values.

# %% [markdown]
# <p style='color:#7159c1; letter-spacing:2px; font-family:JetBrains Mono; font-size:150%'>0.2 | Calculating P-Values and Explaining P-Hacking</p>
#
# Okay, you may be wondering: *"How to calculate the p-value in order to know if the Null Hypothesis must be rejected or fail to be rejected?"*. It depends on the type of Hypothesis Testing we are applying, but all types follow the same logic, they just add up:
#
# 1. the probability to observe the desired result in the Distribution - `it tells how rare is the desired result`;
# 2. the probability of obeservating other results that is equally rare to the desired result - `it tells how many rare events are likely the desired result`;
# 3. the probability of observating rarer or more extreme results to the desired result - `it tells how many rarer events are to the desired result`.
#
# In a nutshell, the more observations of equally or rarer results, the higher is the p-value and the greater are the odds to fail to reject the Null Hypothesis.
#
# ---
#
# Now, I am going to blow up your mind once again, even though the p-value is smaller enough to reject the Null Hypothesis, there are situations we cannot reject 🤯. It happens due to an antiethical behavior called **P-Hacking**.
#
# Picture this, consider that we get a sample of shounen and seinen animes, calculate their means, apply a T-Test (do not worry about it now, we will cover it later) for Hypothesis Testing and get a p-value higher than 0.05, then, we can say that the Null Hypothesis failed to be rejected.
#
# But, just in order to get more confidence, we get another sample of shounen and seinen animes, do the same steps and conclude that we failed to reject H0. We do it over and over again and in all experiments get the same conclusion. After taking 429 experiments, we finally took one where the p-value is smaller than the Significance Level. So we concluded that we can finally reject H0, right? Nope! It is wrong!!
#
# Even though in this last experiment we say we can reject H0, we did other 429 experiments comproving the inverse, so what do you think? It would be wrong and antiethical assuming only the result of the last experiment and discarding the result of the other experiments only to get the desired - and manipulated - Null Hypothesis rejection, right? The correct behavior here is to fail to reject the Null Hypothesis!!
#
# <figure style='text-align:center'>
#     <img style='border-radius:20px' src='./assets/12-p-hacking.png' alt='P-Hacking Example - the result from a single test cannot invalidate the major tests with similar results' />
#     <figcaption style='text-align: center'>Figure 12 - P-Hacking Example - the result from a single test cannot invalidate the major tests with similar results. By <a href='https://www.youtube.com/watch?v=HDCOUXE3HMM'>StatQuest with Josh Starmer - p-hacking: What it is and how to avoid it!©</a>, at 02:17 minutes.</figcaption>
# </figure>
#
# I assume you already got the glimpse of how p-hacking works and why it is not cool to do. However, here is another example that you must avoid: we take another sample of shounen and seinen animes and got a p-value equals to 0.06. Since it is pretty close to the Significance Level, we add 2 or 3 more elements into our sample and get a p-value equals to 0.03, concluding that the Null Hypothesis must be rejected. Once again, it is anthietical and the correct behavior is to fail to reject H0.
#
# Once an experiment is done, we cannot change the size and/or the elements of the sample only to have a chance to get the desired result, for instance, to have the chance to reject the Null Hypothesis when it should actually be failed to be rejected. To avoid it, there are techniques to calculate a great sample size for the testings and we will cover how to do it using **Statistical Power**.
#
# > **P-Hacking: Number of Experiments** - `it is not ethical and allowed to take a bunch of experiments until to achieve the desired result. If the major experiments got a p-value higher than the Significance Level and only a few ones got a p-value smaller than, the correct behavior is to fail to reject H0`;
#
# > **P-Hacking: Sample Size** - `also, it is not ethical and allowed to modify the sample size until to achieve the desired result`.

# %% [markdown]
# <p style='color:#7159c1; letter-spacing:2px; font-family:JetBrains Mono; font-size:150%'>0.3 | Statistical Power and Power Analysis</p>
#
# Besides the **P-Hacking**, we have to deal with another problem: the situation where we failed to reject the Null Hypothesis when it should be rejected instead - **Error Type 2**. But do not worry, because **Statistical Power** and **Power Analysis** are here to solve both of them for us.
#
# Kicking off with **Statistical Power**, it is the probability that we will correctly reject the Null Hypothesis, being **80% (0.80)** a common used value. Then, if we take a Hypothesis Testing and the choosen Statistical Power is 80%, we are literally saying that: *"If we conclude rejecting the Null Hypothesis, we have 80% of probability that our conclusion is correct."*. It may be kind of confusing when you think about it and the Confidence Level, but relax, I will wrap everything up in the end and all your doubts will disappear!!
#
# So, just stick into your mind that Statistical Power is the probability of correct rejecting the Null Hypothesis and 80% is the standard value for many cases.
#
# ---
#
# However, only determining that the Statistical Power is 80% nothing will change, we will still have to deal with p-hacking and the Error Type 2. So we use the **Power Analysis** in order to put the Statistical Power into action!!
#
# With Power Analysis we determine a great size for our samples before taking the testings using the Statistical Power as a parameter. So at the same time we avoid p-hacking, we also avoid Error Type 2, killing two birds with one stone.
#
# To calculate the Power Analysis for sample size, we have to follow four steps:
#
# 1. Determine the Power: `80% (0.80)`;
#
# 2. Determine the Significance Level: `5% (0.05)`;
#
# 3. Estimate the Overlap between the distributions;
#
# 4. Calculate the Sample Size accordingly to the Hypothesis Test to be Applied.
#
# <br />
# <br />
#
# About the third step, **Overlap** is the region that exists between the two populations distributions in the testings. The higher is the region, the larger must be the sample size in order to give us 80% of Power, and vice-versa. The images below ilustrate it.
#
# <figure style='text-align:center'>
#     <img style='border-radius:20px' src='./assets/13.0-overlap.png' alt='Small overlap between two distributions needs a small sample size to give 80% of Power' />
#     <figcaption style='text-align: center'>Figure 13 - Small overlap between two distributions needs a small sample size to give 80% of Power. By <a href='https://www.youtube.com/watch?v=VX_M3tIyiYk'>StatQuest with Josh Starmer - Power Analysis, Clearly Explained!!!©</a>, at 03:35 minutes.</figcaption>
# </figure>
#
# <br />
#
# <figure style='text-align:center'>
#     <img style='border-radius:20px' src='./assets/13.1-overlap.png' alt='Small overlap between two distributions needs a small sample size to give 80% of Power' />
#     <figcaption style='text-align: center'>Figure 14 - Small overlap between two distributions needs a small sample size to give 80% of Power. By <a href='https://www.youtube.com/watch?v=VX_M3tIyiYk'>StatQuest with Josh Starmer - Power Analysis, Clearly Explained!!!©</a>, at 03:50 minutes.</figcaption>
# </figure>
#
# <br />
#
# <figure style='text-align:center'>
#     <img style='border-radius:20px' src='./assets/13.2-overlap.png' alt='Big overlap between two distributions needs a large sample size to give 80% of Power' />
#     <figcaption style='text-align: center'>Figure 15 - Big overlap between two distributions needs a large sample size to give 80% of Power. By <a href='https://www.youtube.com/watch?v=VX_M3tIyiYk'>StatQuest with Josh Starmer - Power Analysis, Clearly Explained!!!©</a>, at 03:55 minutes.</figcaption>
# </figure>
#
# <br />
#
# <figure style='text-align:center'>
#     <img style='border-radius:20px' src='./assets/13.3-overlap.png' alt='Big overlap between two distributions needs a large sample size to give 80% of Power' />
#     <figcaption style='text-align: center'>Figure 16 - Big overlap between two distributions needs a large sample size to give 80% of Power. By <a href='https://www.youtube.com/watch?v=VX_M3tIyiYk'>StatQuest with Josh Starmer - Power Analysis, Clearly Explained!!!©</a>, at 04:00 minutes.</figcaption>
# </figure>
#
# <br />
# <br />
#
# The overlap region between the two distributions must be quantified before calculating the sample size. When quantified, it is called **Effect Size (d)** and its equation is given as:
#
# $$
# \text{d} = \frac{ \left| \overline X(a) - \overline X(b) \right| } { \sqrt{\frac{\sigma(a)^2 + \sigma(b)^2} {2}} }
# $$
#
# where:
#
# $$
# \left| \overline X(a) - \overline X(b) \right| \text{: difference between the estimated means}
# $$
#
# <figure style='text-align:center'>
#     <img style='border-radius:20px' src='./assets/13.4-overlap.png' alt='Estimated difference between the distributions mean' />
#     <figcaption style='text-align: center'>Figure 17 - Estimated difference between the distributions mean. By <a href='https://www.youtube.com/watch?v=VX_M3tIyiYk'>StatQuest with Josh Starmer - Power Analysis, Clearly Explained!!!©</a>, at 13:09 minutes.</figcaption>
# </figure>
#
# <br />
# <br />
#
# $$
# \sqrt{\frac{\sigma(a)^2 + \sigma(b)^2} {2}} \text{: pooled estimated standard deviations}
# $$
#
# <figure style='text-align:center'>
#     <img style='border-radius:20px' src='./assets/13.5-overlap.png' alt='Pooled Estimated difference between the distributions standard deviation' />
#     <figcaption style='text-align: center'>Figure 18 - Pooled Estimated difference between the distributions standard deviation. By <a href='https://www.youtube.com/watch?v=VX_M3tIyiYk'>StatQuest with Josh Starmer - Power Analysis, Clearly Explained!!!©</a>, at 13:14 minutes.</figcaption>
# </figure>
#
# <br />
# <br />
#
# About the fourth step, we first choose what Hypothesis Testing we are going to apply and then, since the sample size calculation differ a little bit for each test, we use the statsmodels python librbary to do the calculations for the corresponding Hypothesis Testing. You can see all available power solvers from stats models in its [documentation](https://www.statsmodels.org/dev/generated/statsmodels.stats.power.tt_solve_power.html).

# %% [markdown]
# <p style='color:#7159c1; letter-spacing:2px; font-family:JetBrains Mono; font-size:150%'>0.4 | Wrapping Up</p>
